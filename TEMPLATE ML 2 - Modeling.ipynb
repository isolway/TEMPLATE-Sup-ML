# %% [markdown]
# # 2 - MODELING (TEMPLATE SUP ML)

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive

# %% [markdown]
# # Load cleaned dataset

# %%
drive.mount('/content/drive')

# %%
df = pd.read_csv('...')
df.shape

# %%
df.head(3)

# %% [markdown]
# # Undersampling (*CL)

# %% [markdown]
# **NOTA:** SOLO EN CLASIFICACIÓN cuando el ratio de éxitos está MUY DESBALANCEADO (<1%).

# %% [markdown]
# # Split data: Train-Test-Validation

# %% [markdown]
# # Rescaling

# %% [markdown]
# **NOTA:** NO NECESARIO en 1) modelos de arboles de decisión y 2) regresión logística. Guardar el scaler para predict.

# %% [markdown]
# # Model Selection

# %% [markdown]
# Probamos una colección de modelos con el objetivo de conseguir el mejor rendimiento del modelo en los datos de TEST.

# %% [markdown]
# # Optimization of parameters

# %% [markdown]
# Probamos diferentes configuraciones de los parametros del modelo ganador en el torneo de modelos con el objetivo de conseguir el mejor performance del modelo en los datos de TEST.

# %% [markdown]
# # Final Model Evaluation

# %% [markdown]
# Error en VALIDACIÓN, Top features, SHAP values... etc

# %% [markdown]
# # Save model
