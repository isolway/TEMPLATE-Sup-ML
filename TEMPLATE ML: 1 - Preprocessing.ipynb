# %% [markdown]
# # 1 - PREPROCESSING (TEMPLATE SUP. ML)

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive

# %% [markdown]
# # Import data

# %% [markdown]
# **NOTA:** En Machine Learning trabajar con datasets gigantes (>1MM observaciones) tiene un gran coste computacional y no suele significar una mejora en el modelo. En estos casos se recomienda utilizar muestras aleatorias de 200k-500k observaciones.

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/2.3 - Preprocessing & Analysis/data/airbnb_NYC_2019_1.csv')
df.shape
# Out:
# (48907, 19)

# %%
df.head(3)
# Out:
#    Unnamed: 0    id                                 name  host_id  host_name  \
# 0           0  2539   Clean & quiet apt home by the park     2787       John
# 1           1  2595                Skylit Midtown Castle     2845   Jennifer
# 2           2  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaN                NaN
#
# ...

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## EDA: Analysis

# %% [markdown]
# * Analisis univariante
# * Analisis multivariante

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# * Eliminar filas/columnas vacías y columnas irrelevantes
# * Corregir formatos incorrectos
# * Fechas y textos: convertir a variables numericas o categoricas

# %% [markdown]
# ## Nulls: impute values

# %% [markdown]
# * Imputar cero, valor fijo, media o moda

# %% [markdown]
# ## One-Hot-Encoding

# %% [markdown]
# ## Remove Low-Variance

# %% [markdown]
# ## Remove High-Correlation

# %% [markdown]
# # Save cleaned dataset
